# %%
import pandas as pd
data=pd.read_csv('matches.csv')
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2  umpire3
# 0     AY Dandekar       NJ Llong      NaN
# 1  A Nand Kishore         S Ravi      NaN
# 2     Nitin Menon      CK Nandan      NaN
# 3    AK Chaudhary  C Shamshuddin      NaN
# 4             NaN            NaN      NaN

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.player_of_match.value_counts().idxmax()
# Out:
# 'CH Gayle'

# %%
data.city.value_counts().idxmax()
# Out:
# 'Mumbai'

# %%
data.venue.value_counts().idxmax()
# Out:
# 'M Chinnaswamy Stadium'

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.drop('umpire3',inplace=True,axis=1)

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
##to select a row with max win  by runs 
data.loc[data.win_by_runs.idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# Name: 43, dtype: object

# %%
#to selct a row with high win by runs in horizontal representation
data.loc[[data.win_by_runs.idxmax()]]
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2
# 43  Nitin Menon  CK Nandan

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
data.toss_winner.max()
# Out:
# 'Sunrisers Hyderabad'

# %%
data.loc[[data.win_by_wickets.idxmax()]]
# Out:
#    id  season    city        date          team1                  team2  \
# 2   3    2017  Rajkot  2017-04-07  Gujarat Lions  Kolkata Knight Riders
#
#              toss_winner toss_decision  result  dl_applied  \
# 2  Kolkata Knight Riders         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 2  Kolkata Knight Riders            0              10         CA Lynn
#
#                                     venue      umpire1    umpire2
# 2  Saurashtra Cricket Association Stadium  Nitin Menon  CK Nandan

# %%
data.umpire1.value_counts().idxmax()
# Out:
# 'HDPK Dharmasena'

# %%
#winners in ipl year wise
"""
d1={}
l1=[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
for i in l1:
    d1[i]=data[data.season==i].iloc[-1].winner

year=[]
winner=[]

for i,j in  d1.items():
    year.append(i)
    winner.append(j)
df=pd.DataFrame(winner,year)
df.to_csv('winners',header=None)


"""
df=pd.read_csv('matches.csv')
req=df.drop_duplicates(keep='last',subset='season')#keeps the last row of each season 
df1=pd.DataFrame(data=list(req.winner),columns=['winner'],index=list(req.season))
df1.sort_index(ascending=True).to_csv('winners.csv')

# %%
data[data.season==2011].winner.value_counts().idxmax()
# Out:
# 'Chennai Super Kings'

# %%
data[data.season==2011].iloc[-1].winner
# Out:
# 'Chennai Super Kings'

# %%
#checking for team which win more matches in a season win the title or not
d1={}
l1=[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
for i in l1:
    d1[i]=data[data.season==i].winner.value_counts().idxmax() is data[data.season==i].iloc[-1].winner
d1
# Out:
# {2008: True,
#  2009: False,
#  2010: False,
#  2011: True,
#  2012: True,
#  2013: True,
#  2014: False,
#  2015: False,
#  2016: True,
#  2017: True}

# %%
# storing  final match details for  each season into a data frame

data11=[]
for i in l1:
    data11.append(data[data.season==i].iloc[-1])
#print(data11)
data123=pd.DataFrame(data11)
data123.replace({'dl_applied':0},'no',inplace=True)
data123.drop(columns='id',inplace=True)
data123.set_index('date',inplace=True)
data123.to_csv('new_each_season_ipl_final.csv')

# %%
#splitted data frame with each city
g=data.groupby('city')
g.max()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       476    2014  2014-04-29          Sunrisers Hyderabad
# Ahmedabad       540    2015  2015-04-24          Sunrisers Hyderabad
# Bangalore       636    2017  2017-05-19          Sunrisers Hyderabad
# Bloemfontein    165    2009  2009-05-17             Delhi Daredevils
# Cape Town       130    2009  2009-04-26  Royal Challengers Bangalore
# Centurion       172    2009  2009-05-22  Royal Challengers Bangalore
# Chandigarh      622    2017  2017-05-09          Sunrisers Hyderabad
# Chennai         563    2015  2015-05-10          Sunrisers Hyderabad
# Cuttack         497    2014  2014-05-14               Mumbai Indians
# Delhi           635    2017  2017-05-14          Sunrisers Hyderabad
# Dharamsala      450    2013  2013-05-18              Kings XI Punjab
# Durban          169    2009  2009-05-20  Royal Challengers Bangalore
# East London     150    2009  2009-05-08               Mumbai Indians
# Hyderabad       618    2017  2017-05-21          Sunrisers Hyderabad
# Indore          294    2017  2017-04-20  Royal Challengers Bangalore
# Jaipur          442    2013  2013-05-12          Sunrisers Hyderabad
# Johannesburg    174    2009  2009-05-24               Mumbai Indians
# Kanpur          630    2017  2017-05-13               Mumbai Indians
# Kimberley       155    2009  2009-05-11             Rajasthan Royals
# Kochi           278    2011  2011-05-05         Kochi Tuskers Kerala
# Kolkata         631    2017  2017-05-13          Sunrisers Hyderabad
# Mumbai          600    2017  2017-05-16          Sunrisers Hyderabad
# Nagpur          220    2010  2010-04-12             Rajasthan Royals
# Port Elizabeth  162    2009  2009-05-16  Royal Challengers Bangalore
# Pune            605    2017  2017-05-14          Sunrisers Hyderabad
# Raipur          632    2016  2016-05-22          Sunrisers Hyderabad
# Rajkot          607    2017  2017-04-29  Royal Challengers Bangalore
# Ranchi          575    2015  2015-05-22  Royal Challengers Bangalore
# Sharjah         474    2014  2014-04-27          Sunrisers Hyderabad
# Visakhapatnam   629    2016  2016-05-21          Sunrisers Hyderabad
#
#                                       team2                  toss_winner  \
# city
# Abu Dhabi                  Rajasthan Royals             Rajasthan Royals
# Ahmedabad       Royal Challengers Bangalore  Royal Challengers Bangalore
# Bangalore               Sunrisers Hyderabad          Sunrisers Hyderabad
# Bloemfontein               Rajasthan Royals              Kings XI Punjab
# Cape Town       Royal Challengers Bangalore  Royal Challengers Bangalore
# Centurion       Royal Challengers Bangalore  Royal Challengers Bangalore
# Chandigarh              Sunrisers Hyderabad  Royal Challengers Bangalore
# Chennai                 Sunrisers Hyderabad          Sunrisers Hyderabad
# Cuttack                       Pune Warriors        Kolkata Knight Riders
# Delhi                   Sunrisers Hyderabad          Sunrisers Hyderabad
# Dharamsala      Royal Challengers Bangalore               Mumbai Indians
# Durban          Royal Challengers Bangalore  Royal Challengers Bangalore
# East London           Kolkata Knight Riders               Mumbai Indians
# Hyderabad               Sunrisers Hyderabad          Sunrisers Hyderabad
# Indore                       Mumbai Indians  Royal Challengers Bangalore
# Jaipur          Royal Challengers Bangalore          Sunrisers Hyderabad
# Johannesburg    Royal Challengers Bangalore  Royal Challengers Bangalore
# Kanpur                  Sunrisers Hyderabad          Sunrisers Hyderabad
# Kimberley                  Rajasthan Royals             Rajasthan Royals
# Kochi           Royal Challengers Bangalore        Kolkata Knight Riders
# Kolkata                 Sunrisers Hyderabad          Sunrisers Hyderabad
# Mumbai                  Sunrisers Hyderabad          Sunrisers Hyderabad
# Nagpur          Royal Challengers Bangalore  Royal Challengers Bangalore
# Port Elizabeth  Royal Challengers Bangalore  Royal Challengers Bangalore
# Pune            Royal Challengers Bangalore  Royal Challengers Bangalore
# Raipur          Royal Challengers Bangalore          Sunrisers Hyderabad
# Rajkot                  Sunrisers Hyderabad          Sunrisers Hyderabad
# Ranchi                  Sunrisers Hyderabad          Sunrisers Hyderabad
# Sharjah                 Sunrisers Hyderabad          Sunrisers Hyderabad
# Visakhapatnam           Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                toss_decision  result  dl_applied  win_by_runs  win_by_wickets  \
# city
# Abu Dhabi              field     tie           0           93               6
# Ahmedabad              field     tie           0           62               9
# Bangalore              field     tie           1          144              10
# Bloemfontein           field  normal           0           14               6
# Cape Town              field     tie           1           75              10
# Centurion              field  normal           1           38               8
# Chandigarh             field  normal           0           76              10
# Chennai                field     tie           0           97               9
# Cuttack                field  normal           0           44               9
# Delhi                  field  normal           1          146              10
# Dharamsala             field  normal           0          111               6
# Durban                 field  normal           1           78               9
# East London              bat  normal           0           78               7
# Hyderabad              field     tie           1           77               9
# Indore                 field  normal           0            0               8
# Jaipur                 field  normal           0           87              10
# Johannesburg           field  normal           0           18               9
# Kanpur                 field  normal           0            0               8
# Kimberley              field  normal           0           53               7
# Kochi                  field  normal           1           55               7
# Kolkata                field  normal           1           82               9
# Mumbai                 field  normal           0          105              10
# Nagpur                 field  normal           0           13               6
# Port Elizabeth           bat  normal           0           92               7
# Pune                   field  normal           0           97               9
# Raipur                 field  normal           0           15               7
# Rajkot                 field     tie           0           26              10
# Ranchi                 field  normal           0           34               6
# Sharjah                field  normal           0           72               8
# Visakhapatnam          field  normal           1           85               7
#
#                                                             venue
# city
# Abu Dhabi                                    Sheikh Zayed Stadium
# Ahmedabad                            Sardar Patel Stadium, Motera
# Bangalore                                   M Chinnaswamy Stadium
# Bloemfontein                                      OUTsurance Oval
# Cape Town                                                Newlands
# Centurion                                         SuperSport Park
# Chandigarh             Punjab Cricket Association Stadium, Mohali
# Chennai                           MA Chidambaram Stadium, Chepauk
# Cuttack                                          Barabati Stadium
# Delhi                                            Feroz Shah Kotla
# Dharamsala           Himachal Pradesh Cricket Association Stadium
# Durban                                                  Kingsmead
# East London                                          Buffalo Park
# Hyderabad               Rajiv Gandhi International Stadium, Uppal
# Indore                                     Holkar Cricket Stadium
# Jaipur                                     Sawai Mansingh Stadium
# Johannesburg                                New Wanderers Stadium
# Kanpur                                                 Green Park
# Kimberley                                   De Beers Diamond Oval
# Kochi                                               Nehru Stadium
# Kolkata                                              Eden Gardens
# Mumbai                                           Wankhede Stadium
# Nagpur               Vidarbha Cricket Association Stadium, Jamtha
# Port Elizabeth                                   St George's Park
# Pune                                   Subrata Roy Sahara Stadium
# Raipur           Shaheed Veer Narayan Singh International Stadium
# Rajkot                     Saurashtra Cricket Association Stadium
# Ranchi                         JSCA International Stadium Complex
# Sharjah                                   Sharjah Cricket Stadium
# Visakhapatnam   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...

# %%
sum(data.columns.isnull())
# Out:
# 0

# %%
type(data.columns.values)
# Out:
# numpy.ndarray

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index
